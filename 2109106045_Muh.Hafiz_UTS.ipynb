# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Dr.-Fahrul-Agus,MT_Dr.-Fahrul-Agus,MT_StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math_score  reading_score  writing_score
# ...

# %% [markdown]
# ## a. Buat Tabel Distribusi Frekuensi dan Histogram Variabe reading_score dan writing_score dengan jumlah dan lebar interval sebesar 10

# %% [markdown]
# ### Skor Membaca

# %%
interval = pd.interval_range(0,100, freq=10)
frekuensi = pd.cut(df['reading_score'], interval)
frekuensi.value_counts(sort=False).rename_axis("Skor Membaca").reset_index(name="Frekuensi")
# Out:
#   Skor Membaca  Frekuensi
# 0      (0, 10]          0
# 1     (10, 20]          1
# 2     (20, 30]          7
# 3     (30, 40]         19
# 4     (40, 50]         70
# 5     (50, 60]        178
# 6     (60, 70]        238
# 7     (70, 80]        252
# 8     (80, 90]        173
# 9    (90, 100]         62

# %% [markdown]
# #### Skor Menulis

# %%
interval = pd.interval_range(0,100, freq=10)
frekuensi = pd.cut(df['writing_score'], interval)
frekuensi.value_counts(sort=False).rename_axis("Skor Menulis").reset_index(name="Frekuensi")
# Out:
#   Skor Menulis  Frekuensi
# 0      (0, 10]          1
# 1     (10, 20]          2
# 2     (20, 30]          7
# 3     (30, 40]         25
# 4     (40, 50]         89
# 5     (50, 60]        177
# 6     (60, 70]        243
# 7     (70, 80]        248
# 8     (80, 90]        140
# 9    (90, 100]         68

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize=(10,6))
plt.title("Skor Membaca")
plt.xlim([10, 110])
plt.ylim([10, 248])
plt.yticks(np.arange(0, 248, 10))
plt.xticks(np.arange(0,110,10))
plt.hist(df['reading_score'],bins=10,edgecolor="#7f3e87",color="#5dbccf")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title("Skor Menulis")
plt.xlim([10, 110])
plt.ylim([10, 248])
plt.yticks(np.arange(0, 248, 10))
plt.xticks(np.arange(0,110,10))
plt.hist(df['writing_score'],bins=10,edgecolor="#384175",color="#cda9e8")
plt.show()

# %% [markdown]
# ## b. Tentukan nilai Tendensi Central: Rata-rata, Median, Modus, Min dan Max data kedua variable tersebut.

# %%
Tendensi_Central = ['reading_score','writing_score']
df[Tendensi_Central].describe()
# Out:
#        reading_score  writing_score
# count    1000.000000    1000.000000
# mean       69.169000      68.054000
# std        14.600192      15.195657
# min        17.000000      10.000000
# 25%        59.000000      57.750000
# 50%        70.000000      69.000000
# 75%        79.000000      79.000000
# max       100.000000     100.000000

# %% [markdown]
# ## c. Tentukan nilai Variasi: Jangkauan Range, Kisaran Interkuartil, Varians, Standar Deviasi data reading_score dan writing_score

# %%
a = df['reading_score'].max()
b = df['reading_score'].min()
j_range= a-b
interkuartil = df['reading_score'].quantile()
varians = df['reading_score'].var()
std_deviasi = df['reading_score'].std()
print("Nilai Variasi")
print("Jangkauan Range: ",j_range)
print("Kisaran Interkuartil: ",interkuartil)
print("Varians: ",varians)
print("Standar Daviasi: ",std_deviasi)
# Out:
# Nilai Variasi
# Jangkauan Range:  83
# Kisaran Interkuartil:  70.0
# Varians:  213.16560460460462
# Standar Daviasi:  14.600191937252216

# %% [markdown]
# ##  d. Buat Grafik data Variabel reading_score dan writing_score: Histogram, BOX PLOT, dan Tentukan Nilai Skewness dan Kurtosis. Buat interpretasi saudara tentang perbedaan distribusi kedua variable tersebut, terutama pada gambar BOX PLOT dan nilai Skewness - Kurtosisnya.

# %% [markdown]
# #### Histogram

# %%
skor_membaca = df['reading_score']
skor_tulis = df['writing_score']
plt.hist([skor_membaca,skor_tulis], label=['skor_membaca','skor_tulis'])
plt.legend(borderpad=0.5, fontsize=8)
plt.show()

# %% [markdown]
# #### Box plot

# %%
plt.figure(figsize=(8,3))
plt.title('Skor Menulis')
sns.boxplot(data=df,x="writing_score",color='#dba540')
plt.show()

# %%
plt.figure(figsize=(8,3))
plt.title('Skor Membaca')
sns.boxplot(data=df,x="reading_score",color='#cdf779')
plt.show()

# %% [markdown]
# #### Nilai Skewness dan Kurtosis

# %%
print("Nilai Skewness dan Kurtosis")
skw_tulis = df['writing_score'].skew()
skw_baca = df['reading_score'].kurt()
kur_tulis = df['reading_score'].kurt()
kur_baca = df['writing_score'].kurt()
print("Skewness")
print("menulis: ",skw_tulis)
print("membaca: ",skw_baca)
print("")
print("Kurtosis")
print("menulis: ",kur_tulis)
print("membaca: ",kur_baca)
# Out:
# Nilai Skewness dan Kurtosis
# Skewness
# menulis:  -0.28944397150761897
# membaca:  -0.0682654585647704
#
# Kurtosis
# menulis:  -0.0682654585647704
# membaca:  -0.03336461500693577

# %% [markdown]
# #### Dari pemapran data yang ada, bisa disimpulkan bahwa

# %% [markdown]
# ## e. Buat scater plot antara writing_score (dependent variable-Y) versus reading_score (independent variable-X). Tulis interpretasi saudara apakah ada indikasi hubungan liear antar keduanya

# %%
plt.figure(figsize=(8,7))
plt.xlabel("SKor Membaca")
plt.ylabel("Skor Menulis")
plt.scatter(x=df["reading_score"],color='#fab457', y=df["writing_score"],alpha=0.8)
plt.show()
